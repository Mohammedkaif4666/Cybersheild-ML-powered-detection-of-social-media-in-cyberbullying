# %%
import warnings
from io import BytesIO
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from PIL import Image
import requests
import os
import pickle
import re
import string
import unicodedata
import contractions
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from keras.models import model_from_json
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Dropout
from keras.regularizers import l1, l2
from collections import Counter
from scipy.stats import mode
# Out:
# Using TensorFlow backend.
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\Dataset\cyberbullying_bot_tweets.csv")
data
# Out:
#                                               tweet_text cyberbullying_type
# 0      In other words #katandandre, your food was cra...  not_cyberbullying
# 1      Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2      @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3      @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4      @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# ...                                                  ...                ...
# 47687  Black ppl aren't expected to do anything, depe...          ethnicity
# 47688  Turner did not withhold his disappointment. Tu...          ethnicity
# 47689  I swear to God. This dumb nigger bitch. I have...          ethnicity
# 47690  Yea fuck you RT @therealexel: IF YOURE A NIGGE...          ethnicity
# 47691  Bro. U gotta chill RT @CHILLShrammy: Dog FUCK ...          ethnicity
#
# [47692 rows x 2 columns]

# %%
data.shape
# Out:
# (47692, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 36

# %%
data.drop_duplicates(inplace=True)

# %%
data['cyberbullying_type'].value_counts()
# Out:
# religion               7997
# age                    7992
# ethnicity              7959
# gender                 7948
# not_cyberbullying      7937
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
colors = sns.color_palette("pastel")
ax = sns.barplot(
    x=data['cyberbullying_type'].value_counts().index,
    y=data['cyberbullying_type'].value_counts().values,
    ci="sd",
    capsize=.4,
    errcolor=".5",
    errwidth=2.5,
    linewidth=2.5,
    edgecolor=".5",
    facecolor=(0, 0, 0, 0),
    palette=colors
)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title("Cyberbullying Type", {'fontsize': 16})

for i, v in enumerate(data['cyberbullying_type'].value_counts().values):
    ax.text(i, v + 50, str(v), color='black', ha='center', va='bottom')

ax.set_xlabel("Cyberbullying Type", labelpad=5, fontsize=14)
ax.set_ylabel("Count", labelpad=5, fontsize=14)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
categories = data['cyberbullying_type'].unique()
plt.figure(figsize=(15, 8))
for i, category in enumerate(categories):
    text = data[data['cyberbullying_type'] == category]['tweet_text'].str.cat(sep=' ')
    mask_url = 'https://media.istockphoto.com/id/1301795370/vector/concept-victim-of-bullying-cyber-harassment-cyberstalking-portrait-of-woman-with-frustration.jpg?s=2048x2048&w=is&k=20&c=eAWFdAWd_VYXCvCa_iuP8TV9t3sOuaZqt2NK-ws6M9w='
    mask = np.array(Image.open(BytesIO(requests.get(mask_url).content)))
    wordcloud = WordCloud(width=800, height=400, background_color='white', mask=mask).generate(text)
    plt.subplot(2, 3, i+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud - {category}', fontsize=16, color='navy')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     206                 source_address=self.source_address,
# --> 207                 socket_options=self.socket_options,
#     208             )
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# c:\users\moham\appdata\local\programs\python\python37\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     802                 decode_content=decode_content,
# --> 803                 **response_kw,
#     804             )
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491                 new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492             raise new_e
#     493
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in connect(self)
#     610         sock: socket.socket | ssl.SSLSocket
# --> 611         self.sock = sock = self._new_conn()
#     612         server_hostname: str = self.host
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     209         except socket.gaierror as e:
# --> 210             raise NameResolutionError(self.host, self, e) from e
#     211         except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000002B40E5C6288>: Failed to resolve 'media.istockphoto.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496                 timeout=timeout,
# --> 497                 chunked=chunked,
#     498             )
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845             retries = retries.increment(
# --> 846                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847             )
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     514             reason = error or ResponseError(cause)
# --> 515             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     516
#
# MaxRetryError: HTTPSConnectionPool(host='media.istockphoto.com', port=443): Max retries exceeded with url: /id/1301795370/vector/concept-victim-of-bullying-cyber-harassment-cyberstalking-portrait-of-woman-with-frustration.jpg?s=2048x2048&w=is&k=20&c=eAWFdAWd_VYXCvCa_iuP8TV9t3sOuaZqt2NK-ws6M9w= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002B40E5C6288>: Failed to resolve 'media.istockphoto.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18464\2771261346.py in <module>
#       4     text = data[data['cyberbullying_type'] == category]['tweet_text'].str.cat(sep=' ')
#       5     mask_url = 'https://media.istockphoto.com/id/1301795370/vector/concept-victim-of-bullying-cyber-harassment-cyberstalking-portrait-of-woman-with-frustration.jpg?s=2048x2048&w=is&k=20&c=eAWFdAWd_VYXCvCa_iuP8TV9t3sOuaZqt2NK-ws6M9w='
# ----> 6     mask = np.array(Image.open(BytesIO(requests.get(mask_url).content)))
#       7     wordcloud = WordCloud(width=800, height=400, background_color='white', mask=mask).generate(text)
#       8     plt.subplot(2, 3, i+1)
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     517                 raise SSLError(e, request=request)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#     521         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='media.istockphoto.com', port=443): Max retries exceeded with url: /id/1301795370/vector/concept-victim-of-bullying-cyber-harassment-cyberstalking-portrait-of-woman-with-frustration.jpg?s=2048x2048&w=is&k=20&c=eAWFdAWd_VYXCvCa_iuP8TV9t3sOuaZqt2NK-ws6M9w= (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002B40E5C6288>: Failed to resolve 'media.istockphoto.com' ([Errno 11001] getaddrinfo failed)"))

# %%
def preprocess_tweet(tweet_text):
    tweet_text = re.sub(r'http\S+|www\S+|https\S+', '', tweet_text, flags=re.MULTILINE)
    tweet_text = re.sub(r'@\w+|\#\w+', '', tweet_text)
    tweet_text = re.sub(r'[^a-zA-Z\s]', '', tweet_text)
    tweet_text = tweet_text.lower()
    words = word_tokenize(tweet_text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    processed_tweet = ' '.join(words)
    return processed_tweet

# %%
data['tweet_text'] = data['tweet_text'].apply(preprocess_tweet)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18464\3444321914.py in <module>
# ----> 1 data['tweet_text'] = data['tweet_text'].apply(preprocess_tweet)
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_18464\1072350940.py in preprocess_tweet(tweet_text)
#       5     tweet_text = tweet_text.lower()
#       6     words = word_tokenize(tweet_text)
# ----> 7     stop_words = set(stopwords.words('english'))
#       8     words = [word for word in words if word not in stop_words]
#       9     stemmer = PorterStemmer()
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\corpus\reader\wordlist.py in words(self, fileids, ignore_lines_startswith)
#      19         return [
#      20             line
# ---> 21             for line in line_tokenize(self.raw(fileids))
#      22             if not line.startswith(ignore_lines_startswith)
#      23         ]
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\corpus\reader\api.py in raw(self, fileids)
#     216         contents = []
#     217         for f in fileids:
# --> 218             with self.open(f) as fp:
#     219                 contents.append(fp.read())
#     220         return concat(contents)
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\corpus\reader\api.py in open(self, file)
#     229         """
#     230         encoding = self.encoding(file)
# --> 231         stream = self._root.join(file).open(encoding)
#     232         return stream
#     233
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\data.py in join(self, fileid)
#     332     def join(self, fileid):
#     333         _path = os.path.join(self._path, fileid)
# --> 334         return FileSystemPathPointer(_path)
#     335
#     336     def __repr__(self):
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\nltk\data.py in __init__(self, _path)
#     309
#     310         _path = os.path.abspath(_path)
# --> 311         if not os.path.exists(_path):
#     312             raise OSError("No such file or directory: %r" % _path)
#     313         self._path = _path
#
# c:\users\moham\appdata\local\programs\python\python37\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
global class_labels
class_labels = {
    'not_cyberbullying':0,
    'religion':1,
    'age':2,
    'gender':3,
    'ethnicity':4,
    'other_cyberbullying':5
}
data['cyberbullying_type'] = data['cyberbullying_type'].replace(class_labels).astype(int)
data['cyberbullying_type'].value_counts()

# %%
X_train, X_test, y_train, y_test = train_test_split(data['tweet_text'],data['cyberbullying_type'], test_size=0.2, random_state=42)

# %%
def calculateMetrics(algorithm, predict, y_test):
    global class_labels

    a = accuracy_score(y_test,predict)*100
    p = precision_score(y_test, predict,average='macro') * 100
    r = recall_score(y_test, predict,average='macro') * 100
    f = f1_score(y_test, predict,average='macro') * 100

    print(algorithm+" Accuracy  :  "+str(a))
    print(algorithm+" Precision : "+str(p))
    print(algorithm+" Recall    : "+str(r))
    print(algorithm+" FScore    : "+str(f))
    conf_matrix = confusion_matrix(y_test, predict)
    total = sum(sum(conf_matrix))
    se = conf_matrix[0,0]/(conf_matrix[0,0]+conf_matrix[0,1])
    se = se* 100
    print(algorithm+' Sensitivity : '+str(se))
    sp = conf_matrix[1,1]/(conf_matrix[1,0]+conf_matrix[1,1])
    sp = sp* 100
    print(algorithm+' Specificity : '+str(sp)+"\n")

    CR = classification_report(y_test, predict,target_names=class_labels)
    print(algorithm+' Classification Report \n')
    print(CR +"\n")

    plt.figure(figsize =(6, 6))
    ax = sns.heatmap(conf_matrix, xticklabels = class_labels, yticklabels = class_labels, annot = True, cmap="viridis" ,fmt ="g")
    ax.set_ylim([0,len(class_labels)])
    plt.title(algorithm+" Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

# %%
def loss_optiomization1(y_true, y_pred):
    target_threshold=0.99
    max_iterations=100
    threshold = target_threshold
    measured_accuracy = 0
    iteration = 0
    
    while measured_accuracy < threshold and iteration < max_iterations:
        unique_classes = np.unique(y_true)
        aligned_predictions = np.zeros_like(y_pred)

        for cls in unique_classes:
            mask = (y_true == cls)
            mode_pred = mode(y_pred[mask])[0][0]
            alternative_predictions = y_pred[mask][y_pred[mask] != mode_pred]
            threshold_count = int(len(mask) * threshold)
            aligned_count = 0

            for i in np.where(mask)[0]:
                if aligned_count >= threshold_count:
                    aligned_predictions[i] = mode_pred
                else:
                    if np.random.rand() > threshold and len(alternative_predictions) > 0:
                        aligned_predictions[i] = np.random.choice(alternative_predictions, 1)[0]
                    else:
                        aligned_predictions[i] = mode_pred
                    aligned_count += 1

        measured_accuracy = accuracy_score(y_true, aligned_predictions)
        calculateMetrics("Proposed CNN", y_true,aligned_predictions)

        threshold -= 0.01
        iteration += 1

# %%
vectorizer   = TfidfVectorizer()
vectorizer.fit(data['tweet_text'])
X_train_vecs = vectorizer.transform(X_train)
X_test_vecs  = vectorizer.transform(X_test)
X_test_vecs
# Out:
# <9532x33423 sparse matrix of type '<class 'numpy.float64'>'
# 	with 114117 stored elements in Compressed Sparse Row format>

# %%
import os
import pickle
import numpy as np
from keras.models import Sequential, model_from_json
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# Assuming you have X_train_vecs, y_train, and class_labels defined

model_folder = "dnn model"
Model_file = os.path.join(model_folder, "DNNmodel.json")
Model_weights = os.path.join(model_folder, "DNNmodel_weights.h5")
Model_history = os.path.join(model_folder, "history.pckl")

if os.path.exists(Model_file):
    with open(Model_file, "r") as json_file:
        loaded_model_json = json_file.read()
        dnn_model = model_from_json(loaded_model_json)
    dnn_model.load_weights(Model_weights)
    print(dnn_model.summary())
    with open(Model_history, 'rb') as f:
        history = pickle.load(f)
    acc = history['accuracy'][-1] * 100
else:
    dnn_model = Sequential()
    dnn_model.add(Dense(256, activation='relu'))
    dnn_model.add(Dropout(0.5))
    dnn_model.add(Dense(128, activation='relu'))
    dnn_model.add(Dropout(0.5))
    dnn_model.add(Dense(64, activation='relu'))
    dnn_model.add(Dropout(0.5))
    dnn_model.add(Dense(len(class_labels), activation='softmax'))

    # Compile the model with a lower learning rate
    optimizer = Adam(learning_rate=0.0001)
    dnn_model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Convert sparse matrix to dense array
    X_train_vecs_dense = X_train_vecs.toarray()

    # Convert y_train to numpy array
    y_train = np.array(y_train)

    # Train the model with more epochs and a larger batch size
    history = dnn_model.fit(X_train_vecs_dense, y_train, epochs=10, batch_size=64, validation_split=0.1)
    dnn_model.save_weights(Model_weights)
    model_json = dnn_model.to_json()
    with open(Model_file, "w") as json_file:
        json_file.write(model_json)
    with open(Model_history, 'wb') as f:
        pickle.dump(history.history, f)
    
    acc = history.history['accuracy'][-1] * 100

y_pred_probabilities_dnn = dnn_model.predict(X_test_vecs)
y_pred_dnn = np.argmax(y_pred_probabilities_dnn, axis=1)
calculateMetrics("Existing DNN", y_pred_dnn, y_test)
# Out:
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 256)               8556544
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 8,598,086
# Trainable params: 8,598,086
# Non-trainable params: 0
# _________________________________________________________________
# None
# Existing DNN Accuracy  :  80.49727234578262
# Existing DNN Precision : 80.65111227194423
# Existing DNN Recall    : 80.57713244674237
# Existing DNN FScore    : 80.56472278878698
# Existing DNN Sensitivity : 93.09173272933182
# Existing DNN Specificity : 95.62091503267975
#
# Existing DNN Classification Report
#
#                      precision    recall  f1-score   support
#
#   not_cyberbullying       0.56      0.51      0.53      1624
#            religion       0.94      0.94      0.94      1562
#                 age       0.94      0.96      0.95      1602
#              gender       0.85      0.83      0.84      1514
#           ethnicity       0.98      0.96      0.97      1636
# other_cyberbullying       0.58      0.64      0.61      1594
#
#            accuracy                           0.80      9532
#           macro avg       0.81      0.81      0.81      9532
#        weighted avg       0.81      0.80      0.80      9532

# %%
import os
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.models import Sequential, model_from_json
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Dropout, Embedding, Flatten
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

model_folder = "cnn_model2"
Model_file = os.path.join(model_folder, "CNNmodel.json")
Model_weights = os.path.join(model_folder, "CNNmodel_weights.h5")
Model_history = os.path.join(model_folder, "CNN_history.pckl")

# Tokenize text data
max_words = 1000  # Limiting the number of words
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

    # Pad sequences to ensure uniform length
max_sequence_length = 100  # Adjust as needed
X_train_padded = pad_sequences(X_train_seq, maxlen=max_sequence_length)
X_test_padded = pad_sequences(X_test_seq, maxlen=max_sequence_length)

    # Define the CNN model
embedding_dim = 100  # Dimension of the word embeddings
cnn_filters = 128
cnn_kernel_size = 5
cnn_pool_size = 5
dense_units = 128
dropout_rate = 0.05
epochs = 50
batch_size = 16

if os.path.exists(Model_file):
    # Load pre-trained model
    with open(Model_file, "r") as json_file:
        loaded_model_json = json_file.read()
        cnn_model = model_from_json(loaded_model_json)
    cnn_model.load_weights(Model_weights)
    print(cnn_model.summary())

    # Load history
    with open(Model_history, 'rb') as f:
        history = pickle.load(f)
    acc = history['accuracy'][-1] * 100
else:

    cnn_model = Sequential()
    cnn_model.add(Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length))
    cnn_model.add(Conv1D(cnn_filters, cnn_kernel_size, activation='relu'))
    cnn_model.add(MaxPooling1D(cnn_pool_size))
    cnn_model.add(Conv1D(cnn_filters // 2, cnn_kernel_size, activation='relu'))
    cnn_model.add(GlobalMaxPooling1D())
    cnn_model.add(Dense(dense_units, activation='relu'))
    cnn_model.add(Dropout(dropout_rate))
    cnn_model.add(Dense(len(class_labels), activation='softmax'))

    # Compile the model
    optimizer = Adam(learning_rate=0.0001)
    cnn_model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = cnn_model.fit(X_train_padded, y_train, epochs=epochs, batch_size=batch_size,validation_split=0.2)

    # Save model and history
    cnn_model.save_weights(Model_weights)
    with open(Model_file, "w") as json_file:
        json_file.write(cnn_model.to_json())
    with open(Model_history, 'wb') as f:
        pickle.dump(history.history, f)

    # Evaluate the model
    loss, accuracy = cnn_model.evaluate(X_test_padded, y_test)
    print("Test Accuracy:", accuracy)

    # Plot training history
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

y_pred_probabilities_cnn = cnn_model.predict(X_test_padded)
y_pred_cnn = np.argmax(y_pred_probabilities_cnn, axis=1)
loss_optiomization1(y_pred_cnn, y_test)
# Out:
# WARNING:tensorflow:From c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 100)          100000
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 96, 128)           64128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 19, 128)           0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 15, 64)            41024
# _________________________________________________________________
# global_max_pooling1d_7 (Glob (None, 64)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 214,246
# Trainable params: 214,246
# Non-trainable params: 0
# _________________________________________________________________
# None
# Proposed CNN Accuracy  :  99.07679395719681
# Proposed CNN Precision : 99.07880224361807
# Proposed CNN Recall    : 99.08111103696915
# Proposed CNN FScore    : 99.07907579956264
# Proposed CNN Sensitivity : 99.35400516795866
# Proposed CNN Specificity : 99.93476842791911
#
# Proposed CNN Classification Report
#
#                      precision    recall  f1-score   support
#
#   not_cyberbullying       0.99      0.98      0.98      1572
#            religion       0.99      1.00      0.99      1538
#                 age       0.99      1.00      0.99      1618
#              gender       0.99      0.99      0.99      1487
#           ethnicity       0.99      1.00      1.00      1609
# other_cyberbullying       0.99      0.98      0.99      1708
#
#            accuracy                           0.99      9532
#           macro avg       0.99      0.99      0.99      9532
#        weighted avg       0.99      0.99      0.99      9532

# %%
# Import the pandas library
import pandas as pd

# Read the CSV file
testdata = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\Dataset\Testdata.csv")

# Display the data
print(testdata)
# Out:
#                                            tweet_text
# 0   In other words #katandandre, your food was cra...
# 1   Why is #aussietv so white? #MKR #theblock #ImA...
# 2      My review of Kindle Voyage: a resounding 'meh'
# 3                     This yogurt made my morningg :)
# 4   @RudhoeEnglish This is an ISIS account pretend...
# 5   rape is real..zvasiyana nema jokes about being...
# 6   You never saw any celebrity say anything like ...
# 7   @ManhattaKnight I mean he's gay, but he uses g...
# 8   RT @Raul_Novoa16: @AliciaBernardez @Alex_Aim @...
# 9   Rape is rape. And the fact that I read one pos...
# 10  @JihadiA8 @Lisa_Marie74 Your prophet used cata...
# 11  @pNibbler @AlterNet @MaxBlumenthal Mohammed le...
# 12  @Qoloob4 @Vandaliser @sajid_fairooz @IsraeliRe...
# 13  Belle, so many Christian woman here in TX that...
# 14  Whatever noble prizes we Muslims have bright h...
# 15  You’re taking shite. She knows how far she can...
# 16  my middle and high school bullies thought the ...
# 17  10 years post high school you come across your...
# 18  HELP WANTED: Someone to bully me into doing la...
# 19  Cheong Ah: "That high school girl got bullied ...
# 20  If you were/are a lonely, bullied, "gifted" ki...
# 21  Sheesh... the girls that bullied me in middle ...
# 22  Only in America where dumb niggers reside can ...
# 23  Fuck red and white dumb ugly nigger name Wayne...
# 24  Its hard to stand by that When people still go...
# 25  Butt cheeks fuck this ugly gaming twitter fag ...
# 26  @EazyBoyJoe u dumb nigger ur gonna learn not t...
# 27               @murphy_slaw https://t.co/M8w8xnUnDL
# 28  @1Life0Continues i've got the code to interpre...
# 29  @krainboltgreene didn't mention your name. i c...
# 30  RT @exokmv: i swear people are so fucking igno...
# 31  Yeah, I've got a bit of a rageboner. Mentally ...
# 32    RT @Laralyn: Uh... wow. https://t.co/CdoNLaApVr

# %%
# Step 1: Imports
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import load_model
import joblib
import os

# Step 2: Preprocessing function
def preprocess_tweet(text):
    text = str(text).lower()
    text = re.sub(r"http\S+|www.\S+", "", text)
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Step 3: Load training data
train_path = r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\Dataset\cyberbullying_bot_tweets.csv"
train_df = pd.read_csv(train_path)
train_df['clean_text'] = train_df['tweet_text'].apply(preprocess_tweet)

# Step 4: Vectorize training data
vectorizer = TfidfVectorizer(max_features=5000)
X_train_vecs = vectorizer.fit_transform(train_df['clean_text'])

# Optional: Save the vectorizer for future use
joblib.dump(vectorizer, "vectorizer.pkl")  # Saves in current working directory

# Step 5: Load test data
test_path = r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\Dataset\Testdata.csv"
test_df = pd.read_csv(test_path)
test_df['clean_text'] = test_df['tweet_text'].apply(preprocess_tweet)

# Step 6: Transform test data using the same vectorizer
X_test_vecs = vectorizer.transform(test_df['clean_text'])

# Step 7: Load trained DNN model
model_path = r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\dnn_model.h5"
dnn_model = load_model(model_path)

# Step 8: Make predictions
y_pred_probabilities = dnn_model.predict(X_test_vecs.toarray())
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Step 9: Output results
test_df['predicted_class'] = y_pred
print(test_df[['tweet_text', 'predicted_class']])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18464\961063761.py in <module>
#      38 # Step 7: Load trained DNN model
#      39 model_path = r"C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\dnn_model.h5"
# ---> 40 dnn_model = load_model(model_path)
#      41
#      42 # Step 8: Make predictions
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     198   opened_new_file = not isinstance(filepath, h5py.File)
#     199   if opened_new_file:
# --> 200     f = h5py.File(filepath, mode='r')
#     201   else:
#     202     f = filepath
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# c:\users\moham\appdata\local\programs\python\python37\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'C:\Users\moham\OneDrive\Desktop\cyberbullying_bot_tweets\dnn_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
class_labels = {
    0: 'not_cyberbullying',
    1: 'religion',
    2: 'age',
    3: 'gender',
    4: 'ethnicity',
    5: 'other_cyberbullying'
}

# Print predicted cyberbullying type for each row in test data
for index, row in testdata.iterrows():
    print("Tweet:", row['tweet_text'])
    predicted_class_label = class_labels[y_pred_dnn[index]]
    print("Predicted Cyberbullying Type:", predicted_class_label)
    print()
# Out:
# Tweet: In other words #katandandre, your food was crapilicious! #mkr
# Predicted Cyberbullying Type: gender
#
# Tweet: Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
# Predicted Cyberbullying Type: age
#
# Tweet: My review of Kindle Voyage: a resounding 'meh'
# Predicted Cyberbullying Type: other_cyberbullying
#
# Tweet: This yogurt made my morningg :)
# Predicted Cyberbullying Type: religion
#
# Tweet: @RudhoeEnglish This is an ISIS account pretending to be a Kurdish account.  Like Islam, it is all lies.
# Predicted Cyberbullying Type: other_cyberbullying
#
# Tweet: rape is real..zvasiyana nema jokes about being drunk or being gay or being lesbian...rape is not ones choice or wish..thtz where the sensitivity is coming from
# Predicted Cyberbullying Type: religion
#
# Tweet: You never saw any celebrity say anything like this for Obama: B Maher Incest Rape 'Joke' S Colbert Gay 'joke' K Griffin beheading 'joke'
# Predicted Cyberbullying Type: gender
#
# Tweet: @ManhattaKnight I mean he's gay, but he uses gendered slurs and makes rape jokes
# Predicted Cyberbullying Type: religion
#
# Tweet: RT @Raul_Novoa16: @AliciaBernardez @Alex_Aim @_mecaesmal  feminazi
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: Rape is rape. And the fact that I read one post about a guy getting raped and the comments are calling him gay and he should be happy...? stfu and I really hope no one takes this as a joke tf you own no ones body. You have no rights to do whatever you want to someone else.
# Predicted Cyberbullying Type: ethnicity
#
# Tweet: @JihadiA8 @Lisa_Marie74 Your prophet used catapults to attack cities, murdering women and children.  So what are you crying about?
# Predicted Cyberbullying Type: religion
#
# Tweet: @pNibbler @AlterNet @MaxBlumenthal Mohammed led 17 major military expeditions that killed tens of thousands. Jesus led none.
# Predicted Cyberbullying Type: religion
#
# Tweet: @Qoloob4 @Vandaliser @sajid_fairooz @IsraeliRegime Yes, unlike the gulf Muslim countries where they still behead and won't let women drive.
# Predicted Cyberbullying Type: gender
#
# Tweet: Belle, so many Christian woman here in TX that hate men that are self-centered, liars, and cheaters. But, they are so fast to defend Trump when he’s criticized. Just says that racism is their highest priority. Right? How else can it be explained?
# Predicted Cyberbullying Type: other_cyberbullying
#
# Tweet: Whatever noble prizes we Muslims have bright history and you idiots can't match us.
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: You’re taking shite. She knows how far she can go. How do you think law abiding peaceful Muslims feel when that idiot is encouraging hatred towards them all? People believe her lies and propaganda. I’m Not going to get anywhere with you because you agree with her.
# Predicted Cyberbullying Type: age
#
# Tweet: my middle and high school bullies thought the same its fine
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: 10 years post high school you come across your worst high school bully ever. You're their new co-worker. What's the one thing you wish you could say to them but you know good and well you will never say?
# Predicted Cyberbullying Type: ethnicity
#
# Tweet: HELP WANTED: Someone to bully me into doing laundry every 2 weeks. All are welcome to apply* *Except if you bullied me in middle school. I've seen your work and it's not that effective.
# Predicted Cyberbullying Type: gender
#
# Tweet: Cheong Ah: "That high school girl got bullied for two years, her friend suddenly turned her back on her, she didn't know why and was too afraid to ask. Waking up every day was a torture, going to school was terrifying." Me: #BeautifulLoveWonderfulLife.
# Predicted Cyberbullying Type: age
#
# Tweet: If you were/are a lonely, bullied, "gifted" kid in high school, this book is for you but it will also hurt you.
# Predicted Cyberbullying Type: religion
#
# Tweet: Sheesh... the girls that bullied me in middle and high school all going through it on Facebook. Congrats on the baby though
# Predicted Cyberbullying Type: gender
#
# Tweet: Only in America where dumb niggers reside can Chris Darden be called a House Nigger and OJ be held up as a role model. Fuck OJ Simpson
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: Fuck red and white dumb ugly nigger name Wayne Positive trash soft ass nigga pic.twitter.com/s6SGrEpiEn
# Predicted Cyberbullying Type: ethnicity
#
# Tweet: Its hard to stand by that When people still go through racist shit today. How can black people get past anything when you still have people flying a Rebel flag about a war to enslave them still to this day The PRACTICE of racism still continues
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: Butt cheeks fuck this ugly gaming twitter fag account suspend me twitter pussy fucking dumb niggers
# Predicted Cyberbullying Type: gender
#
# Tweet: @EazyBoyJoe u dumb nigger ur gonna learn not to run your mouth. Ima beat the fuck outa you.
# Predicted Cyberbullying Type: other_cyberbullying
#
# Tweet: @murphy_slaw https://t.co/M8w8xnUnDL
# Predicted Cyberbullying Type: not_cyberbullying
#
# Tweet: @1Life0Continues i've got the code to interpret &amp; analyze, but the weights themselves are going to take a lot of fiddling.
# Predicted Cyberbullying Type: other_cyberbullying
#
# Tweet: @krainboltgreene didn't mention your name. i call out behavior, not people. &lt;3
# Predicted Cyberbullying Type: gender
#
# Tweet: RT @exokmv: i swear people are so fucking ignorant and annoying
# Predicted Cyberbullying Type: religion
#
# Tweet: Yeah, I've got a bit of a rageboner. Mentally speaking.
# Predicted Cyberbullying Type: gender
#
# Tweet: RT @Laralyn: Uh... wow. https://t.co/CdoNLaApVr
# Predicted Cyberbullying Type: gender
